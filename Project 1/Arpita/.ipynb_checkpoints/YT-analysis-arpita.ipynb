# %%
from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns

# %%
api_key = 'Enter your api key here'

channel_ids = ['UCdxbhKxr8pyWTx1ExCSmJRw', # Girliyapa
               'UCCKjHsAIxvjtWG8KOcLuG8Q', # Alright!
               'UCgM1AQcoM5TRlzsm1e66vrQ', # Hasley India
               'UCNJcSUSzUeFm8W9P7UUlSeQ', # The Viral Fever
               'UCNyeSfUfffmJXwA2_tmNG9A' # The Screen Patti
              ]
channel_ids2 = [

]
youtube = build('youtube', 'v3', developerKey=api_key)

# %% [markdown]
# ## Function to get channel stats

# %%
def get_channel_stats(youtube, channel_ids):
    all_data = []
    request = youtube.channels().list(
                part='snippet,contentDetails,statistics',
                id=','.join(channel_ids))
    response = request.execute() 
    
    for i in range(len(response['items'])):
        data = dict(Channel_name = response['items'][i]['snippet']['title'],
                    Subscribers = response['items'][i]['statistics']['subscriberCount'],
                    Views = response['items'][i]['statistics']['viewCount'],
                    Total_videos = response['items'][i]['statistics']['videoCount'],
                    playlist_id = response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])
        all_data.append(data)
    
    return all_data

# %%
channel_statistics = get_channel_stats(youtube, channel_ids)

# %%
channel_data = pd.DataFrame(channel_statistics)

# %%
channel_data = pd.DataFrame(channel_statistics)

# %%
channel_data['Subscribers'] = pd.to_numeric(channel_data['Subscribers'])
channel_data['Views'] = pd.to_numeric(channel_data['Views'])
channel_data['Total_videos'] = pd.to_numeric(channel_data['Total_videos'])
channel_data.dtypes
# Out:
# Channel_name    object
# Subscribers      int64
# Views            int64
# Total_videos     int64
# playlist_id     object
# dtype: object

# %%
sns.set(rc={'figure.figsize':(10,8)})
ax = sns.barplot(x='Channel_name', y='Subscribers', data=channel_data)

# %%
ax = sns.barplot(x='Channel_name', y='Views', data=channel_data)

# %%
ax = sns.barplot(x='Channel_name', y='Total_videos', data=channel_data)

# %%
channel_data
# Out:
#        Channel_name  Subscribers       Views  Total_videos  \
# 0   The Viral Fever     11100000  1618195705           424
# 1  The Screen Patti      5730000   916003434           288
# 2          Alright!      3260000   451661542           246
# 3         Girliyapa      4590000   527354794           244
# 4      Hasley India      2400000   317620409           172
#
#                 playlist_id
# 0  UUNJcSUSzUeFm8W9P7UUlSeQ
# 1  UUNyeSfUfffmJXwA2_tmNG9A
# 2  UUCKjHsAIxvjtWG8KOcLuG8Q
# 3  UUdxbhKxr8pyWTx1ExCSmJRw
# 4  UUgM1AQcoM5TRlzsm1e66vrQ

# %%
playlist_id = channel_data.loc[channel_data['Channel_name']=='Girliyapa', 'playlist_id'].iloc[0]

# %%
def get_video_ids(youtube, playlist_id):
    
    request = youtube.playlistItems().list(
                part='contentDetails',
                playlistId = playlist_id,
                maxResults = 50)
    response = request.execute()
    
    video_ids = []
    
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])
        
    next_page_token = response.get('nextPageToken')
    more_pages = True
    
    while more_pages:
        if next_page_token is None:
            more_pages = False
        else:
            request = youtube.playlistItems().list(
                        part='contentDetails',
                        playlistId = playlist_id,
                        maxResults = 50,
                        pageToken = next_page_token)
            response = request.execute()
    
            for i in range(len(response['items'])):
                video_ids.append(response['items'][i]['contentDetails']['videoId'])
            
            next_page_token = response.get('nextPageToken')
        
    return video_ids

# %%
video_ids = get_video_ids(youtube, playlist_id)

# %%
video_ids
# Out:
# ['i5S3cVp7f6s',
#  'I9wxnjzMLgE',
#  'q_3HkrdqihI',
#  '87KCt4KMLSQ',
#  'Thsu_BfD1E4',
#  'XMVnfGXqNTQ',
#  'tgJF-z-emy0',
#  'OjoUxLzrdjA',
#  'Spp0aLFJgoE',
#  'j8NsET5PfhU',
#  'ZHv9lwO5xFQ',
#  'B572YgxvPJE',
#  'cU6TMFLH2Wg',
#  'JXRmS9rVEe0',
#  'Y_vPq4e9bG4',
#  '4l8Eo4gBYgc',
#  '3OAMYMKnJPk',
#  'PAijLkFilo0',
#  'XfFvXYII98U',
#  '9hlCjWiKF7w',
#  'rT5CjYCBTVE',
#  'rQQwtL_pdm0',
#  '8NOG0YIOY50',
#  'kGLzJ6CxnEI',
#  '1bhuhJKRxOw',
#  'QK1kPMAChxM',
#  'WUp73ETkSco',
#  '4Y6QEWqN13s',
#  'N57I_sKTFw8',
#  'Bs3xJ8Q0YRQ',
#  'DNCU6n-a6DQ',
#  'h1cbLnU_OSQ',
#  'elcwFtJtWoo',
#  'FcCi6XGp2XU',
#  'NnCYIEQ7rZs',
#  'b_T--fGVUU0',
#  'gG35jcjn1vc',
#  'OqrwWYGrjak',
#  '-CzxKyhGgW0',
#  'HgHjFultlzM',
#  'uZZ_oyce0KI',
#  '-nTLL7r7zPw',
#  'MNv9Yvz0v6w',
#  'nyGzwCKi4WI',
#  'Ayh4RCBHQEY',
#  'lOUlkHKiNXg',
#  '_qZJ6-HLNNg',
#  'Ie98RuHbkbo',
#  'HKIHHjRxtWs',
#  'Yjc7rktzqh8',
#  'bhtnOTLTMFo',
#  '_iCb9l1_7XA',
#  'nRArm7FtEIU',
#  '2P0zJ7xLvjM',
#  '9JepRg-NFh0',
#  'v2Gd1EnzlFU',
#  'WuxbQdnRrLM',
#  '6KMgp9_NVCU',
#  'FfUl166pgds',
#  'zWY09YWAbYM',
#  'v3EaRMTUTOw',
#  '9hq4HuxQErI',
#  'qWMx7p24NTQ',
#  '3zguD38AD34',
#  'W0CJMNdZG-8',
#  '4ntJr-H-7BA',
#  'yYoxCUVcBU0',
#  'KOwYXWsJ_NA',
#  'OhyXxKSwaUc',
#  'iwbCMj4V5LI',
#  'wehUwNciOAs',
#  'Uh4TQdWOA3E',
#  'q7nrFbDXdQk',
#  'aHWfZ2dv8Q4',
#  'FJ-oPpO2WdM',
#  'fvWfftUOwoU',
#  'Py3tzuL3cZ0',
#  'g9J69AfD7EE',
#  'HluUKUxSZx0',
#  'N2d1AeAt1oA',
#  'tdgt_JPUmto',
#  'yLATxq0Yg7w',
#  'NIm5GL0iCpk',
#  'GueguQdHPXE',
#  '9f13M0oBmXg',
#  'yAe4DZLGlGY',
#  't3JTtqvawfg',
#  'm1xLvNlxC1o',
#  'QKMHpJ_UVj0',
#  'WZ6rh364gRg',
#  'JW2XxpveBrA',
#  'FwvVryYLi7k',
#  'FYFWsZibhNE',
#  'xUcILbIBoig',
#  'SG6zLrbAngk',
#  'Gxl7G-XvbIQ',
#  'ElgL4EVpyO4',
#  'fA9pKeBgcN4',
#  '5W3C2KIu_FE',
#  'Gg79G1loNFc',
#  'uIT1_AKxTik',
#  'DfKUCjXldRU',
#  'nSMGWmRviJI',
#  'vySf-BvvrfI',
#  'J-wvRJ37oyQ',
#  'JDRGWCwcuyI',
#  'ZDo36uznhjE',
#  'Lw3EnvjwH20',
#  'fvw1cxXCVPo',
#  'KAruWy9nTKE',
#  'deHNv_YzATI',
#  'NYXMXagVzcU',
#  'bQF_vpotGpI',
#  'vPMqePb30K0',
#  'kL3XKbqMqKI',
#  'EyS72aiTcRE',
#  'VwqWoL_IYX8',
#  '1zuiwtCSJ5A',
#  'g1RvN6x0BQk',
#  'vmEG8g3fmIY',
#  'gfzvtF3aP4M',
#  'F1lsBFQ99AU',
#  'Zwt9HSVzkMk',
#  'Mv451HWle7U',
#  'Mj7rKgyzjRI',
#  'LgegMh8KxbI',
#  'hEKbQCR1-zE',
#  'ytJdQF1NhiU',
#  'B5Duuonftc0',
#  '0EekSxJyft4',
#  '9dDRpCn2d34',
#  '4Mxpv5njnmY',
#  'p-D4bzm9w8g',
#  'or2zN6KcyrA',
#  'UI-DVEhevY8',
#  'K00thCdH2sw',
#  'tQeQy9khdGQ',
#  'hw3BNT6pWqc',
#  'S1O3VDrXHx0',
#  '5jPcxUyDhWQ',
#  'F-8Wd3T1QNY',
#  'WqXgCmmP9aI',
#  'HDbCLeReGh4',
#  'Jn5cKRvVlq8',
#  'TNs-RdaPMDM',
#  'MN_J6jtLdh4',
#  'rkJQidYWDhY',
#  '1t-JthF9DKw',
#  'AwUl-dV_dN8',
#  'l7RAok_xO0M',
#  'cGxYxeOaQjI',
#  'Gn8FoUjeVt0',
#  'LOccdzGw8MU',
#  '0vRl6vbVPJQ',
#  'iYlvuUebP90',
#  'nxYRlmyb8uU',
#  'aZGTqkAzBOI',
#  'H6xo21Z683Y',
#  'P3-Q0Iyqk0w',
#  'rBLcz_yMCkk',
#  'KKukaI1Fg14',
#  'XrkieMNZQCA',
#  'mlK-Hzsw41U',
#  'I393lFFujGM',
#  'SiaYByT_FlU',
#  'f3XtTvnbRW4',
#  'sJozh_eYqe0',
#  'r-HFCBwkRNs',
#  'Zug-4-OLcgI',
#  'b8UoC23jhPc',
#  'yndWwA65snY',
#  'jntOiUVaMBM',
#  '0KmGufcm82I',
#  'Ap_mLDtPylw',
#  'i5yiiURC59Y',
#  'ddB5TbFLrgo',
#  '_UEzrVgM7ok',
#  'B1UcVlzL2cc',
#  'S3fja9w2-iQ',
#  'feSyFLyQdZI',
#  '9m7mloa2L8k',
#  'xOZjtBBdVNM',
#  'ZfZiSfw--0I',
#  'ixPIjt5or-g',
#  's5H7g9x4O-0',
#  'u2EdVVKlgNs',
#  '_Zhz8hF00pE',
#  'B76D5tdiQAc',
#  'VtoG2LTugpA',
#  'qjQhlwQg6rM',
#  'XE2J9bw52RI',
#  'u2lq8YDmhqI',
#  '9zmbOS9eFuE',
#  '5HxbnNpXFU4',
#  'oy8AOs82o6E',
#  'ZCY7yhgmNG4',
#  't6iHERJl_rE',
#  'qJH1SnoBKlQ',
#  'qpRm8eLK880',
#  'OZO9obKSEmU',
#  'vIJwOe4D_xE',
#  '7Ty1LlEAjbM',
#  'RaClqCzY9i0',
#  'fhxayRNEtuQ',
#  'nuYDMbI_Akk',
#  '2sUG33ci3Xk',
#  'Ah1zgG5Glxg',
#  'Zzs6wTGDD2A',
#  'z1OWh9rQf2I',
#  'uYpl0z6LX0k',
#  'cSRT0W6P1xw',
#  'lzI9ilVNzno',
#  '3iKiWnqESYY',
#  'Jvv0O7jLabk',
#  'ZX4VaWeXLA4',
#  'ILUt0cwwrZY',
#  'fESv7on2OaU',
#  'QmOpyyoDdWk',
#  'tWJUn70BxZg',
#  'OHvTKDDiXEk',
#  'ViTpO8wsFmU',
#  'd3q74UIvmGc',
#  'Z1QqF6z3AXQ',
#  'C_2X7dkWIkc',
#  'lpUVzKXycyM',
#  '4SlXEfvut5c',
#  'gEplV0FN_W0',
#  'OuCmsGvXh-Y',
#  '07Vhdxy_Mwc',
#  'j035pvmbQ0g',
#  'MqBVkI0nNUU',
#  '-fr4V-Z9rO4',
#  '9qgv-2xoI7k',
#  'eeGzDo_EPxc',
#  'ECX9ca6VspA',
#  'yhBSqw434e8',
#  'r16Tfs-3fIY',
#  'mHOVIyffPlw',
#  'xLLxUvdmQpw',
#  'oNBmWstLZp0',
#  'q_Tw62JPijg',
#  'MudzWRLTHCw',
#  'Pjup7KjJUWc',
#  'uTVAnuln6bg']

# %% [markdown]
# ## Function to get video details

# %%
def get_video_details(youtube, video_ids):
    all_video_stats = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
                    part='snippet,statistics',
                    id=','.join(video_ids[i:i+50]))
        response = request.execute()
        
        for video in response['items']:
            video_stats = dict(Title = video['snippet']['title'],
                               Published_date = video['snippet']['publishedAt'],
                               Views = video['statistics']['viewCount'],
                               Likes = video['statistics']['likeCount'],
                               Favorite = video['statistics']['favoriteCount'],
                               Comments = video['statistics']['commentCount']
                               )
            all_video_stats.append(video_stats)
            
    
    return all_video_stats

# %%
video_details = get_video_details(youtube, video_ids)

# %%
video_data = pd.DataFrame(video_details)

# %%
video_data['Published_date'] = pd.to_datetime(video_data['Published_date']).dt.date
video_data['Views'] = pd.to_numeric(video_data['Views'])
video_data['Likes'] = pd.to_numeric(video_data['Likes'])
video_data['Favorite'] = pd.to_numeric(video_data['Favorite'])
video_data['Views'] = pd.to_numeric(video_data['Views'])
video_data
# Out:
#                                                  Title Published_date  \
# 0     When Girls Drunk Dial Ft. Nidhi Sahu | Girliyapa     2022-06-17
# 1                     When Jo stood up for her friends     2022-06-14
# 2                           What do women really want?     2022-06-13
# 3    Girls and Phir se Bargaining Ft. Khushbu Baid ...     2022-06-10
# 4                                   Demanding Customer     2022-06-07
# ..                                                 ...            ...
# 239  To Stick or Not to Stick | Ladies Room Bakchod...     2016-04-17
# 240  Girliyapa EP 01 | Why Should Hot Girls Have Al...     2016-03-18
# 241            The Period Song | Girliyapa Unoriginals     2016-03-07
# 242     Girls Buying Condoms | Girliyapa's ChickiLeaks     2015-12-01
# 243  Fashion Waley Babu Ft. BADSHAH | Girliyapa Uno...     2015-08-26
#
#         Views   Likes  Favorite Comments
# 0      116498    6435         0      245
# 1        1809      66         0        2
# 2       31261    1183         0       17
# 3      286192   16587         0      195
# 4       60278    1997         0       12
# ..        ...     ...       ...      ...
# 239   6032605   81651         0     1579
# 240  17387519  429958         0    11158
# 241   6811536  198025         0     5067
# 242  12288711  158571         0     3117
# 243   3914563   31207         0      767
#
# [244 rows x 6 columns]

# %%
top10_videos = video_data.sort_values(by='Views', ascending=False).head(10)

# %%
top10_videos
# Out:
#                                                  Title Published_date  \
# 45                                Every Introvert Ever     2022-01-09
# 228  "Mom, I'm not a virgin!" | Women's Day Special...     2017-03-06
# 240  Girliyapa EP 01 | Why Should Hot Girls Have Al...     2016-03-18
# 195           Mom, Dadi Aur Period | Girliyapa M.O.M.S     2018-03-27
# 242     Girls Buying Condoms | Girliyapa's ChickiLeaks     2015-12-01
# 197  GIRLSPLAINING E01 | Losing His Virginity || Gi...     2018-03-16
# 46                That one Badass woman in every group     2022-01-08
# 189  Girls Buying Condoms Again feat. Captain Nick ...     2018-04-26
# 184  Manju - Kahani Ek Bai Ki | Sanju Trailer Spoof...     2018-06-11
# 234  Girliyapa EP 02 | Ab Ki Baar HR feat. Mallika ...     2016-10-06
#
#         Views    Likes  Favorite Comments
# 45   20115203  1159382         0     1416
# 228  18136985   358011         0    17672
# 240  17387519   429958         0    11158
# 195  15809670   333225         0    12845
# 242  12288711   158571         0     3117
# 197   9056947   168898         0     5887
# 46    8453108   338079         0     1031
# 189   8050564   141536         0     5003
# 184   7976582   194060         0     7733
# 234   7829923   211581         0     4262

# %%
ax1 = sns.barplot(x='Views', y='Title', data=top10_videos)

# %%
video_data
# Out:
#                                                  Title Published_date  \
# 0     When Girls Drunk Dial Ft. Nidhi Sahu | Girliyapa     2022-06-17
# 1                     When Jo stood up for her friends     2022-06-14
# 2                           What do women really want?     2022-06-13
# 3    Girls and Phir se Bargaining Ft. Khushbu Baid ...     2022-06-10
# 4                                   Demanding Customer     2022-06-07
# ..                                                 ...            ...
# 239  To Stick or Not to Stick | Ladies Room Bakchod...     2016-04-17
# 240  Girliyapa EP 01 | Why Should Hot Girls Have Al...     2016-03-18
# 241            The Period Song | Girliyapa Unoriginals     2016-03-07
# 242     Girls Buying Condoms | Girliyapa's ChickiLeaks     2015-12-01
# 243  Fashion Waley Babu Ft. BADSHAH | Girliyapa Uno...     2015-08-26
#
#         Views   Likes  Favorite Comments
# 0      116498    6435         0      245
# 1        1809      66         0        2
# 2       31261    1183         0       17
# 3      286192   16587         0      195
# 4       60278    1997         0       12
# ..        ...     ...       ...      ...
# 239   6032605   81651         0     1579
# 240  17387519  429958         0    11158
# 241   6811536  198025         0     5067
# 242  12288711  158571         0     3117
# 243   3914563   31207         0      767
#
# [244 rows x 6 columns]

# %%
video_data['Month'] = pd.to_datetime(video_data['Published_date']).dt.strftime('%b')

# %%
video_data
# Out:
#                                                  Title Published_date  \
# 0     When Girls Drunk Dial Ft. Nidhi Sahu | Girliyapa     2022-06-17
# 1                     When Jo stood up for her friends     2022-06-14
# 2                           What do women really want?     2022-06-13
# 3    Girls and Phir se Bargaining Ft. Khushbu Baid ...     2022-06-10
# 4                                   Demanding Customer     2022-06-07
# ..                                                 ...            ...
# 239  To Stick or Not to Stick | Ladies Room Bakchod...     2016-04-17
# 240  Girliyapa EP 01 | Why Should Hot Girls Have Al...     2016-03-18
# 241            The Period Song | Girliyapa Unoriginals     2016-03-07
# 242     Girls Buying Condoms | Girliyapa's ChickiLeaks     2015-12-01
# 243  Fashion Waley Babu Ft. BADSHAH | Girliyapa Uno...     2015-08-26
#
#         Views   Likes  Favorite Comments Month
# 0      116498    6435         0      245   Jun
# 1        1809      66         0        2   Jun
# 2       31261    1183         0       17   Jun
# 3      286192   16587         0      195   Jun
# 4       60278    1997         0       12   Jun
# ..        ...     ...       ...      ...   ...
# 239   6032605   81651         0     1579   Apr
# 240  17387519  429958         0    11158   Mar
# 241   6811536  198025         0     5067   Mar
# 242  12288711  158571         0     3117   Dec
# 243   3914563   31207         0      767   Aug
#
# [244 rows x 7 columns]

# %%
videos_per_month = video_data.groupby('Month', as_index=False).size()

# %%
videos_per_month
# Out:
#    Month  size
# 0    Apr    24
# 1    Aug    12
# 2    Dec    24
# 3    Feb    25
# 4    Jan    27
# 5    Jul    13
# 6    Jun    18
# 7    Mar    33
# 8    May    17
# 9    Nov    16
# 10   Oct    19
# 11   Sep    16

# %%
sort_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
             'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# %%
videos_per_month.index = pd.CategoricalIndex(videos_per_month['Month'], categories=sort_order, ordered=True)

# %%
videos_per_month = videos_per_month.sort_index()

# %%
ax2 = sns.barplot(x='Month', y='size', data=videos_per_month)

# %%
video_data.to_csv('Video_Details(Girliyapa).csv')
