# %%
from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns

# %%
api_key = 'Enter your api key'

channel_ids = ['UCF7BExjT2zH_mmyqOB139Dg', # Apni Kaksha
               'UCVJU_IChPMOe8RWkdVQjtfQ', # JEE Wallah 
               'UC7btqG2Ww0_2LwuQxpvo2HQ', # ProgrammingWithHarry 
               'UCVtL0esgwmD3bEZ2iNUjzHw', # Apni Kaksha NEET
               'UCmXZxX_qexEZxhb5_vQKPCw' # Aman Dhattarwal 
              ]
channel_ids2 = [

]
youtube = build('youtube', 'v3', developerKey=api_key)

# %% [markdown]
# ## Function to get channel stats

# %%
def get_channel_stats(youtube, channel_ids):
    all_data = []
    request = youtube.channels().list(
                part='snippet,contentDetails,statistics',
                id=','.join(channel_ids))
    response = request.execute() 
    
    for i in range(len(response['items'])):
        data = dict(Channel_name = response['items'][i]['snippet']['title'],
                    Subscribers = response['items'][i]['statistics']['subscriberCount'],
                    Views = response['items'][i]['statistics']['viewCount'],
                    Total_videos = response['items'][i]['statistics']['videoCount'],
                    playlist_id = response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])
        all_data.append(data)
    
    return all_data

# %%
channel_statistics = get_channel_stats(youtube, channel_ids)

# %%
channel_data = pd.DataFrame(channel_statistics)

# %%
channel_data
# Out:
#            Channel_name Subscribers      Views Total_videos  \
# 0            JEE Wallah      762000  100658342          795
# 1      Apni Kaksha NEET      167000     484184           41
# 2  ProgrammingWithHarry      169000    3511054           80
# 3           Apni Kaksha     1470000  166984104          614
# 4       Aman Dhattarwal     3990000  299449199          452
#
#                 playlist_id
# 0  UUVJU_IChPMOe8RWkdVQjtfQ
# 1  UUVtL0esgwmD3bEZ2iNUjzHw
# 2  UU7btqG2Ww0_2LwuQxpvo2HQ
# 3  UUF7BExjT2zH_mmyqOB139Dg
# 4  UUmXZxX_qexEZxhb5_vQKPCw

# %%
channel_data['Subscribers'] = pd.to_numeric(channel_data['Subscribers'])
channel_data['Views'] = pd.to_numeric(channel_data['Views'])
channel_data['Total_videos'] = pd.to_numeric(channel_data['Total_videos'])
channel_data.dtypes
# Out:
# Channel_name    object
# Subscribers      int64
# Views            int64
# Total_videos     int64
# playlist_id     object
# dtype: object

# %%
sns.set(rc={'figure.figsize':(10,8)})
ax = sns.barplot(x='Channel_name', y='Subscribers', data=channel_data)

# %%
ax = sns.barplot(x='Channel_name', y='Views', data=channel_data)

# %%
ax = sns.barplot(x='Channel_name', y='Total_videos', data=channel_data)

# %%
channel_data
# Out:
#            Channel_name  Subscribers      Views  Total_videos  \
# 0            JEE Wallah       762000  100658342           795
# 1      Apni Kaksha NEET       167000     484184            41
# 2  ProgrammingWithHarry       169000    3511054            80
# 3           Apni Kaksha      1470000  166984104           614
# 4       Aman Dhattarwal      3990000  299449199           452
#
#                 playlist_id
# 0  UUVJU_IChPMOe8RWkdVQjtfQ
# 1  UUVtL0esgwmD3bEZ2iNUjzHw
# 2  UU7btqG2Ww0_2LwuQxpvo2HQ
# 3  UUF7BExjT2zH_mmyqOB139Dg
# 4  UUmXZxX_qexEZxhb5_vQKPCw

# %%
playlist_id = channel_data.loc[channel_data['Channel_name']=='JEE Wallah', 'playlist_id'].iloc[0]

# %%
def get_video_ids(youtube, playlist_id):
    
    request = youtube.playlistItems().list(
                part='contentDetails',
                playlistId = playlist_id,
                maxResults = 50)
    response = request.execute()
    
    video_ids = []
    
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])
        
    next_page_token = response.get('nextPageToken')
    more_pages = True
    
    while more_pages:
        if next_page_token is None:
            more_pages = False
        else:
            request = youtube.playlistItems().list(
                        part='contentDetails',
                        playlistId = playlist_id,
                        maxResults = 50,
                        pageToken = next_page_token)
            response = request.execute()
    
            for i in range(len(response['items'])):
                video_ids.append(response['items'][i]['contentDetails']['videoId'])
            
            next_page_token = response.get('nextPageToken')
        
    return video_ids

# %%
video_ids = get_video_ids(youtube, playlist_id)

# %%
video_ids
# Out:
# ['jdaLTDMmKQg',
#  'rjZWx5cW5yA',
#  'uzWcFQ7cMAg',
#  'xipdasswvC8',
#  'Fqm3ObKpoNA',
#  'WIg6JJE4Mic',
#  'DfB6JQ8weHc',
#  '1t0zqmfqL3s',
#  'rvs-ZW93isM',
#  'Rw-ZTuBRU8o',
#  '6jAIEf3rHBk',
#  'CJr13R8_UDo',
#  'YtEtJxQ1O68',
#  'OajY0s_4iJU',
#  '_-f8i5Tnhw8',
#  '30CtzJ4joEA',
#  'P0_W-_Pofzw',
#  'vydDwgb7bHc',
#  'eR9CYYx8ots',
#  'H8YybnAnI3E',
#  'wK0r2dCbpvM',
#  'bSJzGn8pQvA',
#  'Ht0GpMTht-Y',
#  'xbaLUHjPsRw',
#  'bO1Uz9E-nlI',
#  'r87Nbs7KuTQ',
#  'z8F45RH-79M',
#  'ZpQtsWZUYK4',
#  'efcP0Y1aDW0',
#  'kcpC9qpDjOY',
#  'y5eTm1SkNt4',
#  'i_OLuqtHqgQ',
#  '2S6AUTzPCaU',
#  'FdiOQGvAuuU',
#  '53J7nbLtTnQ',
#  'P2AJSY0wEWo',
#  'mbNRA9oIYQg',
#  'FfRmhuVS57A',
#  'kw12nrsktnc',
#  'B8hRvuAOaYU',
#  '-bC5Pyv7KLI',
#  'bIF0Fmq94Gw',
#  '6yY0Fxwybtc',
#  'Nf0H6ROeCx0',
#  'iPOxMOCOIpY',
#  'YqaaYsckvF8',
#  '-MkCBJ9uMvc',
#  'tkDkeopn8JE',
#  'bl-hlgQlM90',
#  'EpYK9kdKxIk',
#  'stgqsc2sIZ8',
#  'kOQ0TQXurxY',
#  'y9wwx5NjWnQ',
#  'TjCWDGenZ10',
#  'urEsdx9xfKI',
#  '9Zio8pPGiOQ',
#  'P15MmCK0alI',
#  '9suEN7Pxt0g',
#  '4zrpLhKQADA',
#  'wKwRvmCzhQk',
#  'vAI4ws7Whtc',
#  'i4UeTw3FpkY',
#  'Q3ZrdZHvVxI',
#  '_BNvvuQWTWo',
#  'prWVVmpCATs',
#  'r6R0eTC5WbQ',
#  'G1a75zlyn4o',
#  'T1ITvt1geSU',
#  'nEfPXHAostI',
#  'majbTJLR2HE',
#  'gl96wsRtfUI',
#  'QimP6soPpQU',
#  'LdKX8KdgMlY',
#  '1b2nw331trk',
#  'HABs3Rda5-E',
#  'EOj1-kOWHT8',
#  'zh5PlUvebZY',
#  'PCyjvIrNhsg',
#  '9MeSG-6Sjzw',
#  'O6gRv4Anok8',
#  'cQBfjBr9gLU',
#  '2OlzBoSeYb4',
#  'TZ9ZqjJ7TdA',
#  '7c8Gg756nAg',
#  'Q7ey_Xn-fpo',
#  'fzJZ4VLbgAI',
#  'H3KXXQDHjoc',
#  'Zs18JmY167U',
#  'TZmFcHmmv1k',
#  'wZzS9iNSgKo',
#  'jY4vxCf3yzs',
#  'YuYn2LkDM9E',
#  'FHw5qF0dTe8',
#  'h0xc2TGAxPk',
#  'YMRigwZfDjY',
#  'j5Q_fJScDJc',
#  '7F9G4D72fUM',
#  'WxZVG_3a6Kg',
#  'BmxAvNLt_Pg',
#  'EMM9r38uoDk',
#  'vJIUOCilzxA',
#  'PaGTYe8ePd4',
#  'Bow83P_lnMA',
#  'FFLRoBpaZ5k',
#  'fSFiJ6NONZE',
#  '1dwa9qjzbPY',
#  'V2y7pEsg-YA',
#  'FWpKYmgInfY',
#  '0_wcs6YuLgI',
#  'pKqf85rdgOE',
#  'fv7_sFjd8HY',
#  'zEiTyZqP234',
#  '8y0nj7bmtIg',
#  'tIPgYz-33oI',
#  'm3RKS4EZl_w',
#  '06yFPyjWpOA',
#  'VCB2KPB8ttY',
#  'aS1olE5Bj7g',
#  'PhSknru3CFs',
#  'Ttc4fJFclwg',
#  'Q4byiK1SfnA',
#  'NNC8uF6Ol9g',
#  'xDGDcLEl6v4',
#  'jD-amjIWlJg',
#  'Ndr2FxH0A4M',
#  'Da4kV-QNFss',
#  'buM0-ndqiXM',
#  '-OAmojQZ7Bo',
#  'tT18ii8czC4',
#  '0DC_bZyR6kw',
#  '_xcXSquRjdM',
#  'JayTKoNFSSA',
#  'nG7TDrJv-AQ',
#  'IbH-Cmqce0o',
#  'pgPQegBnHFo',
#  'Mg6CzRA_IHc',
#  '9p6yW5B_B0k',
#  'B5IMeYeA1u0',
#  'aIZwg6wvJiE',
#  'TqMSyMun16A',
#  '2NKdZNWMEv4',
#  'ljNLZLtS66c',
#  's0z-H0THr4E',
#  'HvWQUzRwsCo',
#  'uaAjb4RA-Qk',
#  'acRZgWZ8svk',
#  'pDOQ5e5bMLM',
#  'kC9fJH1gj78',
#  '-2U3Czj8E88',
#  'HfKeFfFmNOA',
#  'WnywTOmzjoc',
#  'Iqq5iGv8hqI',
#  '7Z8YnssknYg',
#  'wyb19AcgczI',
#  '4yvb0_ZtzH0',
#  'Aks3ENtKSf8',
#  '-1Nne-ra1lw',
#  '97nC2kmT2sQ',
#  'rbP7xnl46UM',
#  'OpzvzbpqzmY',
#  'nGXjKwC5gbA',
#  'RnLlew2Edow',
#  'cGzITM37yOA',
#  'YEtOldjp4_I',
#  'dGNALKL13ZI',
#  'n1xuq76ChYk',
#  'AktKa35EtDE',
#  'sqjSHWV9Qf0',
#  '1e-qKl7iU_o',
#  'pxYCuWEpujA',
#  'PLClKo-5s8Q',
#  'NEP20efDs64',
#  '091_PzdKsQs',
#  'r5wJKsqGh9s',
#  'yWQ1hAmUnwk',
#  'wQGBrTRouSE',
#  'wWiluGcM2-k',
#  'rXDJqkdlQRo',
#  'iLXESHcHwdo',
#  'RPwo0qGgxbg',
#  'vPG3RgO_JzU',
#  'wS8gAm7dpRU',
#  'HzvBb7AbPps',
#  '3UgL9eGfMks',
#  'b-A8n8Gdw6M',
#  'yE-xRgjDw0c',
#  'OgFJz5HQJtY',
#  'TRM88nKah9A',
#  'vy3cFfALCII',
#  'EfIp8QXIHNg',
#  'B6B-ythY4as',
#  'Zb5T3hhuGkw',
#  'TGx6K6bPS24',
#  'WyRFFij-w9A',
#  '7VkB_th_lDA',
#  '4FIU1tOCW_0',
#  'cahO3_JAAoc',
#  'yFLBvWZejec',
#  '_z4rBS7pmzQ',
#  'mvL8BZx08g0',
#  'L7y7tqsPy_4',
#  'RgwzolyOiUU',
#  'cXZyjCjGtKs',
#  'lz6Hsh085fA',
#  'HtPvZBjPngU',
#  'm70F-Nbk8sQ',
#  '-UqMPQ3DYCg',
#  'uphTyB-qbZs',
#  'iNzpUTrm3DU',
#  '7ggf0jh3ZqE',
#  'aZ6M_gWA5sY',
#  'O0nD7gsRgcI',
#  'OgaVCv0Pzdw',
#  'p_HW7fdSQJ8',
#  'vfmKZ-dRQ6s',
#  'Z5WyFubuUUg',
#  '6ZFxlYLqly8',
#  'aNGCCiUylZI',
#  'JPKpDeH5HBc',
#  'nc7SRyQfz8A',
#  '3n80pAGC2d4',
#  '1vxoueq2jP0',
#  'M-PuvX2ZxQk',
#  'oQXoMiKr22k',
#  'zFy-Uhkw3Mw',
#  'Usl3XhIiQe4',
#  'Ong4BtKW9z8',
#  'qmqK6weGDPA',
#  'BFaU8gGRDXE',
#  'h4Oek9Me0Ss',
#  'MiSCN9HsRv0',
#  'MNVeTyINtaE',
#  'uhwh3nBIAVY',
#  'bukc6afm4ic',
#  'p7vIrTXJpp8',
#  'qmVXW-pfk3A',
#  'rgd1iQbX1K8',
#  '-_PQCU7nunA',
#  'C3GwDJH_7eU',
#  'Tqx8N6S7H7k',
#  '1jwYSPZBtMI',
#  'AadAIAEB6aA',
#  'TnFUYXuQkZ8',
#  'UPWGHF7njTI',
#  'TJI-EcIB1yg',
#  'jtYxPq6x-2U',
#  '3K9GCdpqvR4',
#  '0T-bziCp2cc',
#  'iQFVBs9JDP8',
#  'pMx5-CD6O5U',
#  'IAEUwmIh2CU',
#  'FJOJ9_fByF8',
#  'Y092I16mANs',
#  'B0vTRZNACKg',
#  'll9PWk0TfCw',
#  'uxBYyjD-uEI',
#  'ZrPaKme0kMg',
#  '1LBi0XYZuoU',
#  'Kseh7NdSLZo',
#  'UWSrSyeoin0',
#  'xqg5_iDi-_4',
#  'QPzbCyfMSUg',
#  'ue8D3n3aG6U',
#  'VswqF0V41Js',
#  'mTZaF-svjw0',
#  'f5bxZICRJbQ',
#  'jz3fOlcdfo4',
#  'hBw0lKd2dzw',
#  '66ofDfd5mD8',
#  'ny7e8w3O9Zw',
#  'x9HasmhEFS4',
#  'gdhzOIum0p8',
#  'rzEKiQGiOBY',
#  'Jb4HOclS1ko',
#  'HzYijLwvlNM',
#  '2zAky1re0G0',
#  'txppqsjg5PA',
#  'v9YNXMCG-4g',
#  'TDfhpYIDd6Q',
#  'hVaMRFJn8KI',
#  'ypuN1dcuDf8',
#  'lNWlp672gzs',
#  'hdCpaAddQ8o',
#  '-uvkWchGKxs',
#  '7eN_tddYVls',
#  'PaOOmKpHWco',
#  'dt9q6lchkPw',
#  'Bv4Ww5IsnYQ',
#  'Sby5zGJ_Dnw',
#  'KT6zqGfDQTM',
#  'F4sLrjf_kqo',
#  'c7HsefGP-hE',
#  'p9724By7OFg',
#  'lQbTKaMRLg4',
#  'BNxwlLFEScY',
#  'HA1Fwzp12ZI',
#  '15Q2SFKWPAQ',
#  'yH-GgZHBdYg',
#  'C4k-l2C0ZVE',
#  'U8J-18rmMjk',
#  'hmHwq2Crsk4',
#  'DMnpn8WbgiM',
#  'hh6TTXP32C0',
#  'JKEHMlrACgo',
#  'z2JRpSNF5ww',
#  'knUw9TB7ZHM',
#  'cxMR-zH1SxE',
#  '2v_7gI_6eBQ',
#  'saXIb5T1oEs',
#  'o7lK-MsR7As',
#  'dQIvzIFROLM',
#  'N9gb_uIIc74',
#  '_jRKitFTXKo',
#  '_lENFM6z3kY',
#  'oE0isd-wlwI',
#  'FEst-L-YUOY',
#  'uKaRo87uN0o',
#  'j-2gu_i6u6w',
#  'x_59j7wB_70',
#  'LbZuEc_oZDU',
#  'vr6DYwwlo2o',
#  'oqqpdjlJ42w',
#  '1Eyd0viXGrw',
#  'cyP3fmJ4OFc',
#  'y4QVtdIKQDM',
#  'oMl2MALp0iw',
#  'G-rKguGyDpE',
#  '8N2CHjx59Hs',
#  'osBznypB0bY',
#  'Z2J5R5k6WyE',
#  '_K5MFvBtQrI',
#  'zmREjF-O180',
#  '_mNwcTi_lA8',
#  'hWvVeqG2lCM',
#  'VJDV8ZkzosI',
#  'KAuUeaA6dpw',
#  'N32UTduBvHU',
#  'PEwCpYtP0C8',
#  '_zA3HoiSl_A',
#  '7iSHPUO5Mf0',
#  'RxXXBKDtIlg',
#  'BXHEBnNeAZs',
#  'qaJa2p-Djpo',
#  'TtpFxoCzPsA',
#  'Tw-2JkyPmBY',
#  '91I2GGkPstY',
#  'J0TuC1TVjm8',
#  'eL1R_yfzQ4c',
#  'pNgsztLEQ6o',
#  'nTMyDe_5Nm0',
#  'sIJlEM-f76A',
#  '8wq0zSAatS0',
#  'XvmQsSt0ZRE',
#  'sSCqBU0Uak4',
#  'GngSA4Upr2g',
#  'bzQIddeGM3Y',
#  '4lt1mIYLo4A',
#  'FhFpIIRBEvU',
#  'x99JCP_7pOI',
#  'HqJxWdp8ziI',
#  'R6Zsfv0Mrzk',
#  '7z9GNjl1EFY',
#  'ra4DXktHAoE',
#  'GZeN4L03sEA',
#  'P-a5NxPLcN0',
#  'hF66Ecq-jcY',
#  'yYF9LbEBgNs',
#  'WEx_Kv2kO2k',
#  'nldsl9MzHa8',
#  'C9BvoF5Kb0I',
#  '6U-l_z_niJc',
#  'u2qjBKAVY5w',
#  '23SxL6VJB0o',
#  'AntzMbyXgZQ',
#  'u7-JV-7CyIA',
#  'jxhNoM9KCp4',
#  'z4fBKgB0a7w',
#  '_Tw3OabH6Qw',
#  'G7tyr32pO0o',
#  'fozk7zPRcZc',
#  'ruw36UrfXn0',
#  'XSO5mC0n6h8',
#  'XliqKDMkrSE',
#  'P1CU6NVHCNQ',
#  'AEHeBTnfDWc',
#  'a_sca--OP5c',
#  'QXIYLTPLVQY',
#  'iqQFkXnqIH8',
#  'APeB6lWlVlg',
#  'nKAFyaQpIeQ',
#  'jgaU8F0ylJo',
#  'YxRDcTt23uI',
#  'lDC8aJoxpEo',
#  'uyYpLPSjVoQ',
#  'eJsfIS01IRI',
#  'C5kh9R3Y2xk',
#  'w1pm0h3lUPc',
#  'fD6G0Zqn-L4',
#  'DKrx1-yLkMM',
#  'Rk2hDM9sXmQ',
#  'tckaYFcl-pg',
#  '02v_HPu_D8U',
#  'zZp21zmicpo',
#  '_EdoKJRfEoU',
#  'BrkgTX2wU3k',
#  'f-sdeh4WT14',
#  'DdRxmPasqJA',
#  'xT6L0Ev9H0Q',
#  'La3b2JU1uzY',
#  '6UEhLCK5yeg',
#  'Y-AGNBLR3k4',
#  '-vuYvvqFQc4',
#  'T0NO8aJwwMc',
#  'lFTtCNE9pPs',
#  'xtFGCe6hALY',
#  'pVBhYMsP_n0',
#  'KtUZC5t7m7A',
#  'AHhU_qyINsc',
#  'AajhdnNrJR8',
#  'zzXOTTTbMnk',
#  'M-MyIfm-0dY',
#  'o-ypQvZxQoc',
#  'iMXQ7SlhqZY',
#  'iVdwa0B0_MM',
#  'd2wlt1gd_R4',
#  'B_chFF-FgOc',
#  'arJ8Q8tSQGc',
#  'u04-n1b9G8k',
#  'Vzxuhd94G54',
#  'mcRHBwJ_3lg',
#  '0RrNwu5zToA',
#  'O9rFKIsjKHk',
#  'GY-auI-i2-0',
#  '3_jLXEW8pcI',
#  'HrPSQQAfFKQ',
#  '51okCj6Xf3U',
#  'FdQhelnlOqA',
#  '_QDF6fn3kNg',
#  'SNMSq7jg8Jc',
#  'GDUfwkekN3E',
#  '00hltGoN3Yw',
#  's0bI8tEaJD8',
#  'PCmjSrUy9wY',
#  '0FHVcFv5mV0',
#  'sThyAya6XK4',
#  'oZk7Ntrf_DQ',
#  'P2eLwT6zr4Y',
#  '6lUYbzWQBFk',
#  '-hbmDgPRL6Q',
#  '6cFmz2UaT9M',
#  'v3HQdjJeT2Y',
#  '9BGKVIF0C-c',
#  'BqyssncB9Mg',
#  'DrHA6kAiWcE',
#  'IqdawV_VhZY',
#  'hddIEMpxNws',
#  'aTN5-arJo3Y',
#  'KxOgWA2DT-U',
#  '1wrmPJA20n4',
#  'FjQnvi7VAlQ',
#  'ijb5l6uo6UU',
#  'ZxTk9mN3XnM',
#  'abnmoNNpOEU',
#  'm4DFYiubH_w',
#  'At2xTIML8Dk',
#  '3mCP_jx8U8Y',
#  'oO3mXJC1OA0',
#  'MAm6VTUOIvE',
#  'GUgPa3DAMNw',
#  'vin8L43XXQM',
#  'EBAaxRdlL-0',
#  'UYgWh4QenCg',
#  'IHuJPW6bgWM',
#  '-1JsSKaBI1k',
#  'eMolwsg-Uqk',
#  'oNF72WTOKv4',
#  'avpntclJTeA',
#  'DucLqv5u8sw',
#  '-hnQ96DtGUI',
#  'JIXkwmIEfdA',
#  'veMYiuzGO1w',
#  'W5iC7EnyMEo',
#  '53dOXGWKn00',
#  'nEaIdiYW9Os',
#  '9EB_CLTZf5s',
#  'k3cox6rpRQA',
#  'BEEwpaK6goc',
#  'ZVUd0YQjwOE',
#  'iNzY840YtHg',
#  'r38agJ_cTNw',
#  'r25X-dmzno4',
#  'B5XcXCjW600',
#  'i8apXvt5rg8',
#  'D4akGi7xoUc',
#  'ggACAxVsvi4',
#  'czvhZ35rw5U',
#  'DU4VBcclGwA',
#  'Y0d5WhJr2fw',
#  'vrnV8ZOOWjU',
#  '-eWhQTF7kpE',
#  'oEe7ioicUeg',
#  'GXHsqvSyWj4',
#  'cLOAqeeynJk',
#  'K5QD2f1jPYE',
#  '3s1HMuIzGzk',
#  'rUKiGgPlkMc',
#  'dOt0R7ZDlw4',
#  'JNv0rvMwp0A',
#  'sKmZzIr79FY',
#  'yxHdInR7TmQ',
#  'YSvULrPuKyI',
#  'nBCrdDNdXfY',
#  '_tMRomNssuc',
#  'W4TtB50Safo',
#  'ePPg4ORwOUQ',
#  'v7En1kjQKfA',
#  'Y8kDuQiUU8o',
#  'fmigO_uFO1s',
#  'ZLBGGY70hAI',
#  '-be0E6mqEbA',
#  '-fedxIyOe68',
#  'OUg1lga0c9o',
#  'twM-YQP_XHM',
#  'fcStYKMapxU',
#  'Tn6OcqQ_FuI',
#  '0m_lf6nlKvk',
#  'pOtUxnqQz3Q',
#  'R81b6LjArJ8',
#  'wK3vis3c8mI',
#  'Nn7AX48kcMI',
#  'FaeSwOvos_I',
#  'KtO5vdUp0QY',
#  'xNEBv6Yb4a0',
#  'ljJQD5Td2VE',
#  'S8pUcF4x-FQ',
#  '9RbELJ3vE0s',
#  '1felKuzE9Vg',
#  'QsCO3of_qjg',
#  'NNo3hBChYR0',
#  'M5Q4KwyPEzg',
#  '8owJbGvpPL4',
#  'PPeibuwdwpI',
#  'ZIngU_KIZIs',
#  'nDacyB1EpI8',
#  'uF2iGVXmscc',
#  'NUAzpa50zzM',
#  'bzDHzQUGYAk',
#  'jRMw0aL8kRo',
#  'g4b5uYa2QWk',
#  'ti8dsqROXEI',
#  'PLyRVhRz3Ic',
#  'efUUUuaMH6c',
#  'PQgaE78Fuqw',
#  'EQtuc0lYbzk',
#  'hLvk_BFJzKQ',
#  'c83jm-VIt6U',
#  'tDjjqLyUbeY',
#  'IE4-kJZvx1s',
#  'RQQWoj485JA',
#  '_y_M1brgVzk',
#  '7nJECGfb5SY',
#  'Sr9xb2tJbnY',
#  'AFSBhOs37Ac',
#  'n6CqNwgyXx8',
#  'x3GP6kGhdls',
#  'k7oBNKVsQ94',
#  'QKyEhR5Bqjo',
#  'MmnyF07EM70',
#  'lu4ppAhKELQ',
#  'NJz7q9g9oKA',
#  '35xGpEtSBFo',
#  'T3dQFP2a-vM',
#  'OeWB8wx7gGw',
#  'fUQ2-GGNYig',
#  'ZhRKxTqDcsU',
#  'duESBqn4jOI',
#  '6BWu9DM2H9o',
#  '5aQpsBpvs4E',
#  'QKIduQl07vY',
#  'MyHWFs9FiEc',
#  'y0rW3WXx9WI',
#  'v50T9hzUp14',
#  'nYqh6KXv7ao',
#  'iJxXSvOW50Y',
#  'KCnyHzvdkrY',
#  'OXDiapRlkIk',
#  'Y3e9bKf5hso',
#  '8_hdcAMtyGY',
#  'itbCqpGNusA',
#  'sAgjJ5LaG5g',
#  'iyuRne2G3fI',
#  'jkal74TABMY',
#  'FZWcG-lcEDM',
#  'YxP4ejEyfc4',
#  'fL1xBK5g9p4',
#  'WGABxLfMmI0',
#  'gHz4Q6y6M-g',
#  'zi93cRh9q3c',
#  'VzDzYsSNTM4',
#  'Rs_ueaRm9fc',
#  'uLdPq0597j0',
#  'iTETuO8zuKA',
#  'SbVMbM44WpI',
#  'dWqz8_lb-uo',
#  'nXncRzdFTdg',
#  'kaa9m0-pi78',
#  'bJNvso6Gxcw',
#  'GsAIc5eppm8',
#  'LPj_DSFxiec',
#  'S_n4hl8pQkc',
#  'GNTcMzun7ao',
#  'I9GkJ_AwlbI',
#  '0jKcE9EfZdU',
#  '_Tki2rCD0nA',
#  'Udj42ncY46U',
#  '-IqMLpAdP5s',
#  'ubPzz3B7bkA',
#  'wgJly_hPZT4',
#  'lqC6vdPupbA',
#  'UZpDdE0EgzU',
#  '2Dps7rnGTD0',
#  'PCLR0-AnpNw',
#  '3vSdPXT2DxE',
#  'gcbGF13BAO4',
#  'uJkdqkzW3RI',
#  'LTOZJ0vS_V0',
#  'KSRQEHBqK2Q',
#  '58TzEXeYooE',
#  'FjJ-na5qnas',
#  'i2zV-DgyUp4',
#  'O29VQ5yzTY0',
#  '4KMgTAmygOc',
#  'isa2Idz9KoA',
#  'g1trx5lvato',
#  'jNhSrYTOG54',
#  'K7ljtHLotbk',
#  'mWMqorL9sYM',
#  'M4s6d9aTQdI',
#  '4sB87lgaRvY',
#  'yR8AL6Ixi2c',
#  'FQwvwOsrEhs',
#  'lAmJTaHskqg',
#  'PqFjzAFSGvE',
#  'KyCL5m2WPbI',
#  '09xAwFxkzD8',
#  'UXenHSRmC3s',
#  'HJ1fVsSnS0w',
#  'LRnFJ4anHjE',
#  'e1pmLM-MitY',
#  'EywgRjxjqXU',
#  'xku6I5d3_D4',
#  '5Hcq14cI_Qk',
#  'IkJC1K6aEag',
#  'oM6JrqtieGI',
#  'UFub0p5D9rs',
#  'kX-5vi66b24',
#  'yp2_9VLDhVA',
#  'anhG2y_Mslc',
#  'eI3tKdrpGIA',
#  'Od3AR7B5vsc',
#  'MHkhOt3hbww',
#  'A0U14DCk4zw',
#  'OCXTpws-bWI',
#  'FljkIGhy1iQ',
#  'QrtoJ9KkUpY',
#  'qTP5JfH_2Jg',
#  'O6Ia2v49BaM',
#  'ox7tvEes5yY',
#  'pXaXobjf9GM',
#  'IzNKKL_nWaM',
#  'J6neEUW1ysk',
#  '_aiCTxR1qgc',
#  'laRFmT21E1g',
#  'R1I2q2t9Eg4',
#  'a9GG0EzlP4M',
#  'FyfZ3GpZDzA',
#  '4xUtJ4mw2ao',
#  '3YHb1KYdfJE',
#  'fm1NGfMZMLc',
#  'zyJkmIAda6E',
#  '9mC1pFc4usM',
#  'Xy1UojojZOg',
#  'mv7lQLWUCjE',
#  '6gySDc_Iyh0',
#  'elAQ8J52yOg',
#  'GqOeACec3VA',
#  '1a-7PwGHRn4',
#  'Mol5fEJAU3k',
#  'Wvy1SNRowr4',
#  'lkvQ5yxDaek',
#  'kEUlG3_Ouxs',
#  'oiHn3zjYYSA',
#  'EA4lZrTDAlo',
#  'isdVBP__yyw',
#  'UB5NTmBOPZA',
#  'BfRxAnKhIoI',
#  'CgWDUjYa940',
#  'J_WcUr5uoEw',
#  'JEvHdVvZ2Kc',
#  'FugrbPXmThU',
#  '6KWVERJ6NSQ',
#  'aSQY0tGj43I',
#  '-9LvUVPQDr4',
#  'SCS76MrsUlQ',
#  'FhMLrf1Sghk',
#  'PY0A9JshVdk',
#  'MYjKs20yuCc',
#  'XMDLd5yu86U',
#  'oKE6cwcl7ss',
#  'N5FvVLnn8II',
#  'aW5tgGTzgiE',
#  'djAdR5b-Ejo',
#  'ezj7WyodDmQ',
#  'dvKO5_6xkSg',
#  'na3YhYcjL9c',
#  'uYOUelwlDwQ',
#  'gDyqCOSVflA',
#  'NbhTeZJugiw',
#  'vy8JuPrDEbc',
#  'OHpZ3YmKcWQ',
#  'n3ZC-Jn9aAs',
#  'KixA92Ak-ds',
#  '-F6Nrc3vWGw',
#  'ZbDIDSsOdWY',
#  'u-OmXRe0CuU',
#  'PjaWFga7Lbw',
#  'V7IhNvWMO0A',
#  '9sUxI_QjyT8',
#  'rZez4RYwKRI',
#  'lduvNt193eU',
#  'g3rG5gPeq2A',
#  'vDJS8YIeOjs',
#  'zd9noKezkZs',
#  '4dtMNoAsOUw',
#  '4pDDrJTrCHg',
#  'VM2xAehlxo4',
#  'fOVS_PI4thY',
#  'eHAAx4FL4lo',
#  'u9Oxgid_aaU',
#  'WiolycLduKE',
#  'Mp4SrAn2ygs',
#  '16MgP8aWuWU',
#  'UI3X4FusCCo',
#  'QGg0vAqqQ2Q',
#  'Y6SU-qGruiQ',
#  'ql9SXXGNCWI',
#  '02sqUVHboj8',
#  'ccd6QDHVcCo',
#  'E-eGFJqGusQ',
#  'WbWSwJJjjcQ',
#  '9QilkQufD5I',
#  'ZGbDYoVozYc',
#  'R--fcJ5nafA',
#  'mlfwB9RAG98',
#  'U5qAB_aE6ew',
#  'h0JCckU4igg',
#  'IdZaa50B0hQ',
#  '8fmAODpXMeE',
#  'pR4pfYygTWo',
#  'OKfhCdgizFM',
#  'oy2ZzqzAfaI',
#  'V77wZfttfYE',
#  'FvCLP6hIv8A',
#  'JmIFDPiWMQg',
#  'BduLIld_p7g',
#  'rrUJ8e0Xfh0',
#  'wOts07kACXg',
#  'Wqjd_yEFuYY',
#  'N5B5y4b0myI',
#  'JZ0jMU9iIIE',
#  'DCSfGaEg8Tg',
#  'xk2MaMMQeKs',
#  'WuU7m0LT-uM',
#  'xVYKk4gGvp0',
#  'e7Is5-jBNDo',
#  'UGroErIrdJ4',
#  'THHeijYTfKs',
#  'C7CXnkkOmX8',
#  'RojL6Vlg1J0',
#  'Ng6Y1HOxRDY',
#  'jEtgJutEGBM',
#  '_vnzkmk1QYM',
#  'RtHMBbRB_Gc',
#  'Csoxo16bsqM',
#  'P5_DKoajUT4',
#  'RCzzG8VnOl4',
#  'XGFPDkR4-dg',
#  'Us4B5Rf1qN0',
#  '44PH6NrcHwM',
#  '-6kfIRp8NWY',
#  'iOwi85y9oSE',
#  'cqC0cnzXjHI',
#  'g50vTY3ot_M',
#  'LvDEO27plw0',
#  'pqfA5X4txYo']

# %% [markdown]
# ## Function to get video details

# %%
def get_video_details(youtube, video_ids):
    all_video_stats = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
                    part='snippet,statistics',
                    id=','.join(video_ids[i:i+50]))
        response = request.execute()
        
        for video in response['items']:
            video_stats = dict(Title = video['snippet']['title'],
                               Published_date = video['snippet']['publishedAt'],
                               Views = video['statistics']['viewCount'],
                               Likes = video['statistics']['likeCount'],
                               Favorite = video['statistics']['favoriteCount'],
                               Comments = video['statistics']['commentCount']
                               )
            all_video_stats.append(video_stats)
            
    
    return all_video_stats

# %%
video_details = get_video_details(youtube, video_ids)

# %%
video_data = pd.DataFrame(video_details)

# %%
video_data['Published_date'] = pd.to_datetime(video_data['Published_date']).dt.date
video_data['Views'] = pd.to_numeric(video_data['Views'])
video_data['Likes'] = pd.to_numeric(video_data['Likes'])
video_data['Favorite'] = pd.to_numeric(video_data['Favorite'])
video_data['Views'] = pd.to_numeric(video_data['Views'])
video_data
# Out:
#                                                  Title Published_date  \
# 0    Good Luck & Best Wishes 😇 to all JEE MAIN 2022...     2022-06-22
# 1               JEE MAIN me kal FOD ke aana hai !!! 🔥🔥     2022-06-22
# 2                           Kya PW bhi Badal Jayega? 🥺     2022-06-22
# 3                               "Time" सबसे कीमती है 🔥     2022-06-22
# 4                                     KOTA का इतिहास 🔥     2022-06-21
# ..                                                 ...            ...
# 790  Quadratic Equations in 1 Shot - All Concepts, ...     2021-06-02
# 791  Basic Mathematics in 1 Shot - All Concepts, Tr...     2021-06-01
# 792  Mole Concept in 1 Shot - Every Concepts, Trick...     2021-05-30
# 793  MANZIL Batch - Complete VECTORS in 1 Shot | Day 1     2021-05-28
# 794                    MANZIL Tak Jana Hai Bachhon !!!     2021-05-25
#
#        Views  Likes  Favorite Comments
# 0      13816   8760         0      537
# 1      54024   8660         0      189
# 2      22630   2766         0       60
# 3      28905   4198         0       38
# 4      84624  10488         0       85
# ..       ...    ...       ...      ...
# 790  1554567  50984         0     4589
# 791   707703  32789         0     1163
# 792  2283280  70538         0     3950
# 793  1494843  60974         0     3523
# 794   474664  43365         0     4450
#
# [795 rows x 6 columns]

# %%
top10_videos = video_data.sort_values(by='Views', ascending=False).head(10)

# %%
top10_videos
# Out:
#                                                  Title Published_date  \
# 76   Alakh Sir ने कितने लोगों को रोजगार दिया है? SI...     2022-06-05
# 792  Mole Concept in 1 Shot - Every Concepts, Trick...     2021-05-30
# 785  Atomic Structure in 1 Shot - All Concepts, Tri...     2021-06-06
# 690  Complete ORGANIC CHEMISTRY in 6 Hours - Best R...     2021-07-21
# 180                       Alakh sir SECRET Suggestion🤫     2022-04-28
# 153                                 Bachpan की Maths 😂     2022-05-15
# 790  Quadratic Equations in 1 Shot - All Concepts, ...     2021-06-02
# 147                      "Mehfil" खुद की, चर्चे हमारे😂     2022-05-17
# 793  MANZIL Batch - Complete VECTORS in 1 Shot | Day 1     2021-05-28
# 786  Complex Numbers in 1 Shot - All Concepts, Tric...     2021-06-05
#
#        Views   Likes  Favorite Comments
# 76   3090157  299522         0      666
# 792  2283280   70538         0     3950
# 785  1945813   60658         0     2919
# 690  1798573   54349         0     2775
# 180  1744130  185123         0      362
# 153  1576467  116704         0      904
# 790  1554567   50984         0     4589
# 147  1504073  138775         0      203
# 793  1494843   60974         0     3523
# 786  1327416   45811         0     2503

# %%
ax1 = sns.barplot(x='Views', y='Title', data=top10_videos)
# Out:
# C:\Users\rajha\.conda\envs\YT-env\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2344 (\N{DEVANAGARI LETTER NA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\rajha\.conda\envs\YT-env\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Matplotlib currently does not support Devanagari natively.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\rajha\.conda\envs\YT-env\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2375 (\N{DEVANAGARI VOWEL SIGN E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\rajha\.conda\envs\YT-env\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2325 (\N{DEVANAGARI LETTER KA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\rajha\.conda\envs\YT-env\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2367 (\N{DEVANAGARI VOWEL SIGN I}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\rajha\.conda\envs\YT-env\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2340 (\N{DEVANAGARI LETTER TA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\rajha\.conda\envs\YT-env\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2354 (\N{DEVANAGARI LETTER LA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\rajha\.conda\envs\YT-env\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2379 (\N{DEVANAGARI VOWEL SIGN O}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\rajha\.conda\envs\YT-env\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2327 (\N{DEVANAGARI LETTER GA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\rajha\.conda\envs\YT-env\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2306 (\N{DEVANAGARI SIGN ANUSVARA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\rajha\.conda\envs\YT-env\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2352 (\N{DEVANAGARI LETTER RA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\rajha\.conda\envs\YT-env\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2332 (\N{DEVANAGARI LETTER JA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\rajha\.conda\envs\YT-env\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2366 (\N{DEVANAGARI VOWEL SIGN AA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\rajha\.conda\envs\YT-env\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2342 (\N{DEVANAGARI LETTER DA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\rajha\.conda\envs\YT-env\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2351 (\N{DEVANAGARI LETTER YA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\rajha\.conda\envs\YT-env\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2361 (\N{DEVANAGARI LETTER HA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\rajha\.conda\envs\YT-env\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2376 (\N{DEVANAGARI VOWEL SIGN AI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\rajha\.conda\envs\YT-env\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 128514 (\N{FACE WITH TEARS OF JOY}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\rajha\.conda\envs\YT-env\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 128293 (\N{FIRE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\rajha\.conda\envs\YT-env\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 129323 (\N{FACE WITH FINGER COVERING CLOSED LIPS}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\rajha\.conda\envs\YT-env\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2368 (\N{DEVANAGARI VOWEL SIGN II}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\rajha\.conda\envs\YT-env\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2326 (\N{DEVANAGARI LETTER KHA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\rajha\.conda\envs\YT-env\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2369 (\N{DEVANAGARI VOWEL SIGN U}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\rajha\.conda\envs\YT-env\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2330 (\N{DEVANAGARI LETTER CA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\rajha\.conda\envs\YT-env\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2381 (\N{DEVANAGARI SIGN VIRAMA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\rajha\.conda\envs\YT-env\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2350 (\N{DEVANAGARI LETTER MA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
video_data
# Out:
#                                                  Title Published_date  \
# 0    Good Luck & Best Wishes 😇 to all JEE MAIN 2022...     2022-06-22
# 1               JEE MAIN me kal FOD ke aana hai !!! 🔥🔥     2022-06-22
# 2                           Kya PW bhi Badal Jayega? 🥺     2022-06-22
# 3                               "Time" सबसे कीमती है 🔥     2022-06-22
# 4                                     KOTA का इतिहास 🔥     2022-06-21
# ..                                                 ...            ...
# 790  Quadratic Equations in 1 Shot - All Concepts, ...     2021-06-02
# 791  Basic Mathematics in 1 Shot - All Concepts, Tr...     2021-06-01
# 792  Mole Concept in 1 Shot - Every Concepts, Trick...     2021-05-30
# 793  MANZIL Batch - Complete VECTORS in 1 Shot | Day 1     2021-05-28
# 794                    MANZIL Tak Jana Hai Bachhon !!!     2021-05-25
#
#        Views  Likes  Favorite Comments
# 0      13816   8760         0      537
# 1      54024   8660         0      189
# 2      22630   2766         0       60
# 3      28905   4198         0       38
# 4      84624  10488         0       85
# ..       ...    ...       ...      ...
# 790  1554567  50984         0     4589
# 791   707703  32789         0     1163
# 792  2283280  70538         0     3950
# 793  1494843  60974         0     3523
# 794   474664  43365         0     4450
#
# [795 rows x 6 columns]

# %%
video_data['Month'] = pd.to_datetime(video_data['Published_date']).dt.strftime('%b')

# %%
video_data
# Out:
#                                                  Title Published_date  \
# 0    Good Luck & Best Wishes 😇 to all JEE MAIN 2022...     2022-06-22
# 1               JEE MAIN me kal FOD ke aana hai !!! 🔥🔥     2022-06-22
# 2                           Kya PW bhi Badal Jayega? 🥺     2022-06-22
# 3                               "Time" सबसे कीमती है 🔥     2022-06-22
# 4                                     KOTA का इतिहास 🔥     2022-06-21
# ..                                                 ...            ...
# 790  Quadratic Equations in 1 Shot - All Concepts, ...     2021-06-02
# 791  Basic Mathematics in 1 Shot - All Concepts, Tr...     2021-06-01
# 792  Mole Concept in 1 Shot - Every Concepts, Trick...     2021-05-30
# 793  MANZIL Batch - Complete VECTORS in 1 Shot | Day 1     2021-05-28
# 794                    MANZIL Tak Jana Hai Bachhon !!!     2021-05-25
#
#        Views  Likes  Favorite Comments Month
# 0      13816   8760         0      537   Jun
# 1      54024   8660         0      189   Jun
# 2      22630   2766         0       60   Jun
# 3      28905   4198         0       38   Jun
# 4      84624  10488         0       85   Jun
# ..       ...    ...       ...      ...   ...
# 790  1554567  50984         0     4589   Jun
# 791   707703  32789         0     1163   Jun
# 792  2283280  70538         0     3950   May
# 793  1494843  60974         0     3523   May
# 794   474664  43365         0     4450   May
#
# [795 rows x 7 columns]

# %%
videos_per_month = video_data.groupby('Month', as_index=False).size()

# %%
videos_per_month
# Out:
#    Month  size
# 0    Apr    39
# 1    Aug    18
# 2    Dec    94
# 3    Feb    95
# 4    Jan    90
# 5    Jul    80
# 6    Jun   126
# 7    Mar    57
# 8    May    80
# 9    Nov    80
# 10   Oct    21
# 11   Sep    15

# %%
sort_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
             'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# %%
videos_per_month.index = pd.CategoricalIndex(videos_per_month['Month'], categories=sort_order, ordered=True)

# %%
videos_per_month = videos_per_month.sort_index()

# %%
ax2 = sns.barplot(x='Month', y='size', data=videos_per_month)

# %%
video_data.to_csv('Video_Details(JEE Wallah).csv')
